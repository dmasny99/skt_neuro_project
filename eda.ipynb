# %%
import mne
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# %matplotlib notebook
# Out:
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %%
data = mne.io.read_raw_fif('data/kz_clean/mdd/clean_F155.fif')
# Out:
# Opening raw data file data/kz_clean/mdd/clean_F155.fif...
#     Range : 1500 ... 64499 =      3.000 ...   128.998 secs
# Ready.

# %%
data.plot();
# Out:
# <img src="data:image/png;base64,..." width="800">
